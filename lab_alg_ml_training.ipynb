# %% [markdown]
# <a href="https://colab.research.google.com/github/murillofnc22/labs-bairesdev-ml-training/blob/main/lab_alg_ml_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando as bibliotecas para mostrar imagens.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# Mostrando a imagem original.

# %%
img = mpimg.imread('/content/wat.jpg')
plt.axis('off')
plt.imshow(img)
plt.show()

# %% [markdown]
# Convertendo para escala de cinza.

# %%
if img.max() <= 1.0:
    img = (img * 255).astype(np.uint8)

gray_img = (0.299 * img[:, :, 0] +
            0.587 * img[:, :, 1] +
            0.114 * img[:, :, 2]).astype(np.uint8)

plt.imshow(gray_img, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# Convertendo a imagem para preto e branco.

# %%
if img.max() <= 1.0:
    img = (img * 255).astype(np.uint8)

gray = (0.299 * img[:, :, 0] +
        0.587 * img[:, :, 1] +
        0.114 * img[:, :, 2]).astype(np.uint8)

threshold = np.mean(gray)
bw = np.where(gray > threshold, 255, 0).astype(np.uint8)

plt.imshow(bw, cmap='gray')
plt.axis('off')
plt.show()
